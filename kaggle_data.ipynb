# %%
from jupyter_plotly_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
import plotly.express as px
from dash.dependencies import Input, Output

import pandas as pd
import numpy as np

# %%
covid_df = pd.read_csv("data/covid_19_clean_complete.csv")
covid_confirmed_df = covid_df[covid_df['Confirmed'] > 0]
covid_deaths_df = covid_df[covid_df['Deaths'] > 0]

covid_confirmed_df.head(10)
# Out:
#    Province/State Country/Region      Lat      Long     Date  Confirmed  \
# 49          Anhui          China  31.8257  117.2264  1/22/20          1
# 50        Beijing          China  40.1824  116.4142  1/22/20         14
# 51      Chongqing          China  30.0572  107.8740  1/22/20          6
# 52         Fujian          China  26.0789  117.9874  1/22/20          1
# 54      Guangdong          China  23.3417  113.4244  1/22/20         26
# 55        Guangxi          China  23.8298  108.7881  1/22/20          2
# 56        Guizhou          China  26.8154  106.8748  1/22/20          1
# 57         Hainan          China  19.1959  109.7453  1/22/20          4
# 58          Hebei          China  39.5490  116.1306  1/22/20          1
# 60          Henan          China  33.8820  113.6140  1/22/20          5
#
#     Deaths  Recovered
# 49       0          0
# 50       0          0
# 51       0          0
# 52       0          0
# 54       0          0
# 55       0          0
# 56       0          0
# 57       0          0
# 58       0          0
# 60       0          0

# %%
# take median of lat and long for each country, sum Confirmed
confirmed_grouped_df = covid_confirmed_df.groupby(["Country/Region", "Date"]).agg({'Lat': 'mean',
    'Long': 'mean', 'Confirmed': 'sum'}).reset_index()
confirmed_grouped_df.head(5)
# Out:
#   Country/Region     Date   Lat  Long  Confirmed
# 0    Afghanistan  2/24/20  33.0  65.0          1
# 1    Afghanistan  2/25/20  33.0  65.0          1
# 2    Afghanistan  2/26/20  33.0  65.0          1
# 3    Afghanistan  2/27/20  33.0  65.0          1
# 4    Afghanistan  2/28/20  33.0  65.0          1

# %%
# ensure animation frame is sorted correctly
confirmed_grouped_df['Date'] = pd.to_datetime(confirmed_grouped_df['Date']).dt.date
confirmed_grouped_df = confirmed_grouped_df.sort_values(by=['Date'])
confirmed_grouped_df['log_confirmed'] = np.log(confirmed_grouped_df['Confirmed'])
confirmed_grouped_df.head(5)
# Out:
#       Country/Region        Date        Lat        Long  Confirmed  \
# 2951           China  2020-01-22  30.994279  113.461025        548
# 14277             US  2020-01-22  37.090200  -95.712900          1
# 13552        Taiwan*  2020-01-22  23.700000  121.000000          1
# 7200           Japan  2020-01-22  36.000000  138.000000          2
# 12722    South Korea  2020-01-22  36.000000  128.000000          1
#
#        log_confirmed
# 2951        6.306275
# 14277       0.000000
# 13552       0.000000
# 7200        0.693147
# 12722       0.000000

# %%
# same preprocessing for deaths data
deaths_grouped_df = covid_deaths_df.groupby(["Country/Region", "Date"]).agg({'Lat': 'mean',
    'Long': 'mean', 'Deaths': 'sum'}).reset_index()
deaths_grouped_df['Date'] = pd.to_datetime(deaths_grouped_df['Date']).dt.date
deaths_grouped_df = deaths_grouped_df.sort_values(by=['Date'])
deaths_grouped_df['log_deaths'] = np.log(deaths_grouped_df['Deaths'])
deaths_grouped_df
# Out:
#                Country/Region        Date        Lat        Long  Deaths  \
# 4387                 Honduras  2020-05-25  15.200000  -86.241900     182
# 4326                    Haiti  2020-05-25  18.971200  -72.285200      27
# 4275                   Guyana  2020-05-25   5.000000  -58.750000      11
# 6621                  Moldova  2020-05-25  47.411600   28.369900     261
# 8162               San Marino  2020-05-25  43.942400   12.457800      42
# 9035                    Sudan  2020-05-25  12.862800   30.217600     170
# 4200            Guinea-Bissau  2020-05-25  11.803700  -15.180400       7
# 1357   Bosnia and Herzegovina  2020-05-25  43.915900   17.679100     146
# 6552                   Mexico  2020-05-25  23.634500 -102.552800    7633
# 7741              Philippines  2020-05-25  13.000000  122.000000     873
#
#        log_deaths
# 2093     2.833213
# 2094     2.890372
# 2095     3.258097
# 2096     3.737670
# 2097     4.025352
# 2098     4.406719
# 2099     4.875197
# 2100     4.890349
# 2101     5.141664
# 2102     5.361292
# 2103     5.556828
# 7645     0.000000
# 2114     5.888878
# 2125     6.052089
# 7656     0.000000
# 2126     6.196444
# 7657     0.000000
# 2127     6.333280
# 7658     0.000000
# 2128     6.450470
# 7659     0.000000
# 7660     0.000000
# 2129     6.576470
# 2130     6.690842
# 7661     0.000000
# 7662     0.000000
# 2131     6.807935
# 2104     6.919684
# 7635     0.000000
# 2105     7.013915
# ...           ...
# 9246     7.556428
# 1618     4.867534
# 6828     0.000000
# 1183     0.693147
# 4170     2.995732
# 10379    1.098612
# 4681     7.237778
# 8902    10.197425
# 459      6.146329
# 4605     8.336151
# 1233     1.098612
# 4529     2.302585
# 6418     2.197225
# 4459     6.196444
# 6484     2.302585
# 1291     5.564520
# 380      1.098612
# 10058    5.513429
# 8187     2.397895
# 8961     2.302585
# 4387     5.204007
# 4326     3.295837
# 4275     2.397895
# 6621     5.564520
# 8162     3.737670
# 9035     5.135798
# 4200     1.945910
# 1357     4.983607
# 6552     8.940236
# 7741     6.771936
#
# [10531 rows x 6 columns]

# %%
app = JupyterDash("Covid Dashboard")

app.layout = html.Div([
    html.H1('Covid-19 Tracker'),
    dcc.RadioItems(
        id='type-selector',
        options=[{'label': i, 'value': i} for i in ['confirmed', 'deaths']],
        value='confirmed',
        style={'margin-top': '60px'}
    ),
    dcc.Graph(id='covid-map')
], style={'text-align':'center'})

@app.callback(
    Output('covid-map', 'figure'),
    [Input('type-selector', 'value')])
def update_figure(selected_type):
    df = confirmed_grouped_df if selected_type == 'confirmed' else deaths_grouped_df
    return (
        px.scatter_geo(df,
            lat = df['Lat'],
            lon = df['Long'],
            color=df['log_' + selected_type],
            opacity=0.4,
            hover_name=df['Country/Region'],
            size=df['log_' + selected_type],
            animation_frame=df['Date'].astype(str),
            projection="natural earth")
    )

app
# Out:
# <div>
#   <iframe src="/app/endpoints/39897abfca58420e891fff1561a93a89/" width=800 height=600 frameborder="0"></iframe>
#   <hr/><a href="/app/endpoints/39897abfca58420e891fff1561a93a89/" target="_new">Open in new window</a> for /app/endpoints/39897abfca58420e891fff1561a93a89/
# </div>
