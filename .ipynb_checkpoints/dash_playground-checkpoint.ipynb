# %%
import pandas as pd

# %%
covid_df = pd.read_csv("covid_19_clean_complete.csv")
covid_confirmed_df = covid_df[covid_df['Confirmed'] > 0]

# %%
covid_confirmed_df.head(100)
# Out:
#      Province/State Country/Region      Lat      Long     Date  Confirmed  \
# 49            Anhui          China  31.8257  117.2264  1/22/20          1
# 50          Beijing          China  40.1824  116.4142  1/22/20         14
# 51        Chongqing          China  30.0572  107.8740  1/22/20          6
# 52           Fujian          China  26.0789  117.9874  1/22/20          1
# 54        Guangdong          China  23.3417  113.4244  1/22/20         26
# 55          Guangxi          China  23.8298  108.7881  1/22/20          2
# 56          Guizhou          China  26.8154  106.8748  1/22/20          1
# 57           Hainan          China  19.1959  109.7453  1/22/20          4
# 58            Hebei          China  39.5490  116.1306  1/22/20          1
# 60            Henan          China  33.8820  113.6140  1/22/20          5
# 62            Hubei          China  30.9756  112.2707  1/22/20        444
# 63            Hunan          China  27.6104  111.7088  1/22/20          4
# ...

# %%
print(covid_confirmed_df.groupby(["Country/Region", "Date"]).agg(
    sum_confirmation = pd.NamedAgg(column = "Confirmed", aggfuction = sum),
    me_lat = pd. NamedAgg(column = "Lat", aggfunction = median),
    me_long = pd.NamedAgg(column = "Long", aggfunction =median)))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-4bd94fd79e9e> in <module>
#       1 print(covid_confirmed_df.groupby(["Country/Region", "Date"]).agg(
# ----> 2     sum_confirmation = pd.NamedAgg(column = "Confirmed", aggfuction = sum),
#       3     me_lat = pd. NamedAgg(column = "Lat", aggfunction = median),
#       4     me_long = pd.NamedAgg(column = "Long", aggfunction =median)))
#
# AttributeError: module 'pandas' has no attribute 'NamedAgg'

# %%
grouped_df = covid_confirmed_df.groupby(["Country/Region", "Date"]).agg({'Lat': 'mean',
    'Long': 'mean', 'Confirmed': 'sum'})
grouped_df.shape[1]
# Out:
#                          Lat  Long  Confirmed
# Country/Region Date
# Afghanistan    2/24/20  33.0  65.0          1
#                2/25/20  33.0  65.0          1
#                2/26/20  33.0  65.0          1
#                2/27/20  33.0  65.0          1
#                2/28/20  33.0  65.0          1
#                2/29/20  33.0  65.0          1
#                3/1/20   33.0  65.0          1
#                3/10/20  33.0  65.0          5
#                3/11/20  33.0  65.0          7
#                3/12/20  33.0  65.0          7

# %%
import plotly.express as px
df = px.data.gapminder()

# %%
df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap iso_alpha  \
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314       AFG
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030       AFG
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710       AFG
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138       AFG
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106       AFG
#
#    iso_num
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
